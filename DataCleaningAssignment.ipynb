# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Assignment 1

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 'Budapest_PaRis', 'Brussels_londOn'],
                    'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
                    'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )','12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# 1. Some values in the the FlightNumber column are missing. These numbers are
# meant to increase by 10 with each row so 10055 and 10075 need to be put in
# place. Fill in these missing numbers and make the column an integer column
# (instead of a float column).

# %%
for i in range(1, len(df)):
    if pd.isna(df.loc[i, 'FlightNumber']): 
        df.loc[i, 'FlightNumber'] = df.loc[i - 1, 'FlightNumber'] + 10

df['FlightNumber'] = df['FlightNumber'].astype(int)
df.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# 2. The From_To column would be better as two separate columns! Split each
# string on the underscore delimiter _ to give a new temporary DataFrame with
# the correct values. Assign the correct column names to this temporary
# DataFrame

# %%
temp_df = df['From_To'].str.split('_', expand=True)
temp_df.columns = ['From', 'To']
temp_df
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# 3. Standardise the strings so that only the first letter is
# uppercase (e.g. "londON" should become "London".)

# %%
temp_df['From']=temp_df['From'].str.capitalize()
temp_df['To']=temp_df['To'].str.capitalize()

# %% [markdown]
# 4. Delete the From_To column from df and attach the temporary DataFrame
# from the previous questions

# %%
df = df.drop('From_To', axis=1).join(temp_df)
df.head()
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %% [markdown]
# 5. In the RecentDelays column, the values have been entered into the
# DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value
# should be NaN.
# Expand the Series of lists into a DataFrame named delays, rename the columns
# delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df
# with delays.

# %% [markdown]
# # Assignment 2

# %% [markdown]
# Read the following dataset
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %% [markdown]
#   1. Print total number of records
#   2. Which was the most ordered item? and How many items were ordered?
#   3. What was the most ordered item in the choice_description column?
#   4. Turn the item price into float type
#   5. How much was the revenue for the period in the dataset?
#   6. Print another data frame with only two columns item_name and item_price:
#   7. Delete the duplicates in item_name and quantity
#   8. select only the products with quantity equals to 1
#   9. select only the item_name and item_price columns
#   10. sort the values from the most to less expensive
#   11. What was the quantity of the most expensive item ordered?
#   12. How many times were a Veggie Salad Bowl ordered?

# %%
df=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
len(df)
# Out:
# 4622

# %%
df2=pd.DataFrame(df.item_name.value_counts())
df2.iloc[np.where(df2['count']==max(df2['count']))]
# Out:
#               count
# item_name
# Chicken Bowl    726

# %%
df3=pd.DataFrame(df.choice_description.value_counts())
df3.iloc[np.where(df3['count']==max(df3['count']))]
# Out:
#                     count
# choice_description
# [Diet Coke]           134

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
# How much was the revenue for the period in the dataset?
total_revenue =df.item_price.sum()
print("Total revenue:$",total_revenue)
# Out:
# Total revenue:$ 34500.16

# %%
#Print another data frame with only two columns item_name and item_price:
df2=df[['item_name','item_price']]
df2.head()
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98

# %%
df.drop_duplicates(subset=['item_name','quantity'],keep=False)
# Out:
#       order_id  quantity                            item_name  \
# 445        193         3                                 Bowl
# 506        212         2                        Carnitas Bowl
# 673        279         1                                 Bowl
# 674        279         1    Chips and Mild Fresh Tomato Salsa
# 1257       511         4         Chips and Fresh Tomato Salsa
# 1555       631         2   Chips and Roasted Chili Corn Salsa
# 1653       668         1                  Veggie Crispy Tacos
# 1903       768         2                Barbacoa Crispy Tacos
# 2235       901         4                          Canned Soda
# 2441       970         5                        Bottled Water
# 2550      1010         2  Chips and Tomatillo-Red Chili Salsa
# 2581      1024         2                     Carnitas Burrito
# 2645      1051         3                  Chips and Guacamole
# 2874      1142         2                   Steak Crispy Tacos
# ...

# %%
#select only the products with quantity equals to 1:
a=np.where(df['quantity']==1)
df.iloc[a]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# select only the item_name and item_price columns
df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# sort the values from the most to less expensive
df.sort_values('item_price')
# Out:
#       order_id  quantity            item_name  \
# 261        113         1          Canned Soda
# 1805       730         1          Canned Soda
# 1030       424         1          Canned Soda
# 3020      1201         1          Canned Soda
# 3021      1201         1        Bottled Water
# ...        ...       ...                  ...
# 4547      1807         1     Steak Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
#
#                                      choice_description item_price
# 261                                      [Mountain Dew]     $1.09
# 1805                                           [Sprite]     $1.09
# 1030                                  [Diet Dr. Pepper]     $1.09
# 3020                                  [Diet Dr. Pepper]     $1.09
# 3021                                                NaN     $1.09
# ...

# %%
#  What was the quantity of the most expensive item ordered?
df.iloc[np.where(df['item_price']==max(df['item_price']))]
# Out:
#       order_id  quantity            item_name  \
# 607        250         1     Steak Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 2624      1042         1     Steak Salad Bowl
# 3098      1235         1     Steak Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3356      1346         1  Barbacoa Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4547      1807         1     Steak Salad Bowl
# 4572      1818         1     Steak Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
# How many times were a Veggie Salad Bowl ordered?

df4=pd.DataFrame(df.iloc[np.where(df['item_name']=='Veggie Salad')])
# print(df4)
print("A Veggie Salad Bowl ordered:",len(df4),"times.")
# Out:
# A Veggie Salad Bowl ordered: 6 times.

# %% [markdown]
# # Assignment 3

# %% [markdown]
# Read the following dataset https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv

# %% [markdown]
# 1. Convert the type of the column Year to datetime64
# 2. Set the Year column as the index of the dataframe¶
# 3. Group the year by decades and sum the values
# 4. Select just the 'Murder' and 'Robbery' columns from the DataFrame df and print
# 5. Select the data in rows 3, 4, 8 and in columns 'Murder', 'Robbery'
# 6. Select only the rows where the number of murder is greater than 24,000
# 7. Select the rows the murder is between 20k and 24k (inclusive)
# 8. Calculate the mean murder for each different year in df.
# 9. Sort df first by the values in the 'Murder' in decending order, then by the value in the 'Violent' column in ascending order.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
# Convert the type of the column Year to datetime64:
df['Year']=pd.to_datetime(df['Year'],format='%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
# Set the Year column as the index of the dataframe:
df.set_index(df['Year'],inplace=True)
df.head()
# Out:
#                  Year  Population    Total  Violent  Property  Murder  \
# Year
# 1960-01-01 1960-01-01   179323175  3384200   288460   3095700    9110
# 1961-01-01 1961-01-01   182992000  3488000   289390   3198600    8740
# 1962-01-01 1962-01-01   185771000  3752200   301510   3450700    8530
# 1963-01-01 1963-01-01   188483000  4109500   316970   3792500    8640
# 1964-01-01 1964-01-01   191141000  4564600   364220   4200400    9360
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1960-01-01          17190   107840              154320    912100
# 1961-01-01          17220   106670              156760    949600
# 1962-01-01          17550   110860              164570    994300
# 1963-01-01          17650   116470              174210   1086400
# 1964-01-01          21420   130390              203050   1213200
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01        1855400         328200
# 1961-01-01        1913000         336000
# ...

# %%
# Group the year by decades and sum the values:
# df.groupby(df['Year']).sum(numeric_only=True)
df.head()
# Out:
#                  Year  Population    Total  Violent  Property  Murder  \
# Year
# 1960-01-01 1960-01-01   179323175  3384200   288460   3095700    9110
# 1961-01-01 1961-01-01   182992000  3488000   289390   3198600    8740
# 1962-01-01 1962-01-01   185771000  3752200   301510   3450700    8530
# 1963-01-01 1963-01-01   188483000  4109500   316970   3792500    8640
# 1964-01-01 1964-01-01   191141000  4564600   364220   4200400    9360
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1960-01-01          17190   107840              154320    912100
# 1961-01-01          17220   106670              156760    949600
# 1962-01-01          17550   110860              164570    994300
# 1963-01-01          17650   116470              174210   1086400
# 1964-01-01          21420   130390              203050   1213200
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01        1855400         328200
# 1961-01-01        1913000         336000
# ...

# %%
# Select just the 'Murder' and 'Robbery' columns from the DataFrame df and print:
df2 = df[['Murder','Robbery']]
df2.head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
# Select the data in rows 3, 4, 8 and in columns 'Murder', 'Robbery':
df2.iloc[[3,4,8]]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1968-01-01   13800   262840

# %%
# Select only the rows where the number of murder is greater than 24,000:
df.iloc[np.where(df['Murder']>24000)]
# Out:
#                  Year  Population     Total  Violent  Property  Murder  \
# Year
# 1991-01-01 1991-01-01   252177000  14872900  1911770  12961100   24700
# 1993-01-01 1993-01-01   257908000  14144800  1926020  12218800   24530
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1991-01-01         106590   687730             1092740   3157200
# 1993-01-01         106010   659870             1135610   2834800
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1991-01-01        8142200        1661700
# 1993-01-01        7820900        1563100

# %%
# Select the rows the murder is between 20k and 24k (inclusive):
df.iloc[np.where((df['Murder']>20000) & (df['Murder']<24000))]
# Out:
#                  Year  Population     Total  Violent  Property  Murder  \
# Year
# 1974-01-01 1974-01-01   211392000  10253400   974720   9278700   20710
# 1975-01-01 1975-01-01   213124000  11292400  1039710  10252700   20510
# 1979-01-01 1979-01-01   220099000  12249500  1208030  11041500   21460
# 1980-01-01 1980-01-01   225349264  13408300  1344520  12063700   23040
# 1981-01-01 1981-01-01   229146000  13423800  1361820  12061900   22520
# 1982-01-01 1982-01-01   231534000  12974400  1322390  11652000   21010
# 1986-01-01 1986-01-01   240132887  13211869  1489169  11722700   20613
# 1987-01-01 1987-01-01   242282918  13508700  1483999  12024700   20096
# 1988-01-01 1988-01-01   245807000  13923100  1566220  12356900   20680
# 1989-01-01 1989-01-01   248239000  14251400  1646040  12605400   21500
# 1990-01-01 1990-01-01   248709873  14475600  1820130  12655500   23440
# 1992-01-01 1992-01-01   255082000  14438200  1932270  12505900   23760
# ...

# %%
# Calculate the mean murder for each different year in df:
df.groupby(df['Year'])['Murder'].mean()
# Out:
# Year
# 1960-01-01     9110.0
# 1961-01-01     8740.0
# 1962-01-01     8530.0
# 1963-01-01     8640.0
# 1964-01-01     9360.0
# 1965-01-01     9960.0
# 1966-01-01    11040.0
# 1967-01-01    12240.0
# 1968-01-01    13800.0
# 1969-01-01    14760.0
# 1970-01-01    16000.0
# 1971-01-01    17780.0
# 1972-01-01    18670.0
# 1973-01-01    19640.0
# 1974-01-01    20710.0
# 1975-01-01    20510.0
# 1976-01-01    18780.0
# 1977-01-01    19120.0
# 1978-01-01    19560.0
# 1979-01-01    21460.0
# 1980-01-01    23040.0
# 1981-01-01    22520.0
# 1982-01-01    21010.0
# 1983-01-01    19310.0
# 1984-01-01    18690.0
# 1985-01-01    18980.0
# 1986-01-01    20613.0
# 1987-01-01    20096.0
# 1988-01-01    20680.0
# 1989-01-01    21500.0
# 1990-01-01    23440.0
# 1991-01-01    24700.0
# 1992-01-01    23760.0
# 1993-01-01    24530.0
# 1994-01-01    23330.0
# 1995-01-01    21610.0
# 1996-01-01    19650.0
# 1997-01-01    18208.0
# 1998-01-01    16914.0
# 1999-01-01    15522.0
# 2000-01-01    15586.0
# ...

# %%
# Sort df first by the values in the 'Murder' in decending order, then by the value in the 'Violent' column in ascending order:
df.sort_values(by=['Murder', 'Violent'], ascending=[False, True])
# Out:
#                  Year  Population     Total  Violent  Property  Murder  \
# Year
# 1991-01-01 1991-01-01   252177000  14872900  1911770  12961100   24700
# 1993-01-01 1993-01-01   257908000  14144800  1926020  12218800   24530
# 1992-01-01 1992-01-01   255082000  14438200  1932270  12505900   23760
# 1990-01-01 1990-01-01   248709873  14475600  1820130  12655500   23440
# 1994-01-01 1994-01-01   260341000  13989500  1857670  12131900   23330
# 1980-01-01 1980-01-01   225349264  13408300  1344520  12063700   23040
# 1981-01-01 1981-01-01   229146000  13423800  1361820  12061900   22520
# 1995-01-01 1995-01-01   262755000  13862700  1798790  12063900   21610
# 1989-01-01 1989-01-01   248239000  14251400  1646040  12605400   21500
# 1979-01-01 1979-01-01   220099000  12249500  1208030  11041500   21460
# 1982-01-01 1982-01-01   231534000  12974400  1322390  11652000   21010
# 1974-01-01 1974-01-01   211392000  10253400   974720   9278700   20710
# ...

# %% [markdown]
# # Assignment 4

# %% [markdown]
# Read the following Datasets
# https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv
# https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv
# https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv
# https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv
#
# 1. Join users data to transactions data, keeping all rows from transactions and only matching rows from users (left join)
# 2. Which transactions have a UserID not in users?
# 3. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)
# 4. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)
# 5. Determine which sessions occurred on the same day each user registered
# 6. Build a dataset with every possible (UserID, ProductID) pair (cross join)
# 7. Determine how much quantity of each product was purchased by each user
# 8. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)
# 9. Join each user to his/her first occuring transaction in the transactions table
# 10. Test to see if we can drop columns

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
df1
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
df2
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
df3=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
df3
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
df4=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
df4
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
# Join users data to transactions data, keeping all rows from transactions and only matching rows from users (left join):
transaction_user = df4.merge(df1,how='left',on='UserID')
transaction_user
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
# Which transactions have a UserID not in users?
transaction_user[transaction_user['User'].isna()]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity User Gender  \
# 0              1      2010-08-21     7.0          2         1  NaN    NaN
# 7              8      2014-04-24     NaN          2         3  NaN    NaN
# 8              9      2015-04-24     7.0          4         3  NaN    NaN
#
#   Registered Cancelled
# 0        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN

# %%
# Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)
transaction_user_inner = df4.merge(df1,how='inner',on='UserID')
transaction_user_inner
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              4      2012-08-26     1.0          2         3   Charles
# 3              5      2013-06-06     2.0          4         1     Pedro
# 4              6      2013-12-23     2.0          5         6     Pedro
# 5              7      2013-12-30     3.0          4         1  Caroline
# 6             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2    male  2012-12-21         NaN
# 3    male  2010-08-01  2010-08-08
# 4    male  2010-08-01  2010-08-08
# 5  female  2012-10-23  2016-06-07
# 6  female  2012-10-23  2016-06-07

# %%
# Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)
transaction_user_outer = df4.merge(df1,how='outer',on='UserID')
transaction_user_outer
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 1             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 2             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 3             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 4             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 5             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 6            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 7             NaN             NaN     4.0        NaN       NaN   Brielle
# 8             NaN             NaN     5.0        NaN       NaN  Benjamin
# 9             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 10            9.0      2015-04-24     7.0        4.0       3.0       NaN
# 11            8.0      2014-04-24     NaN        2.0       3.0       NaN
#
# ...

# %%
# Determine which sessions occurred on the same day each user registered
df1['Registered'] = pd.to_datetime(df1['Registered'])
df3['SessionDate'] = pd.to_datetime(df3['SessionDate'])
df1.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      5 non-null      int64
#  1   User        5 non-null      object
#  2   Gender      5 non-null      object
#  3   Registered  5 non-null      datetime64[ns]
#  4   Cancelled   2 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 332.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SessionID    10 non-null     int64
#  1   SessionDate  10 non-null     datetime64[ns]
#  2   UserID       10 non-null     int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 372.0 bytes

# %%
session_user_outer = df3.merge(df1,how='inner',on='UserID')
session_user_outer[session_user_outer['SessionDate']==session_user_outer['Registered']]
# Out:
#    SessionID SessionDate  UserID     User  Gender Registered   Cancelled
# 1          2  2010-08-01       2    Pedro    male 2010-08-01  2010-08-08
# 8          9  2013-07-17       4  Brielle  female 2013-07-17         NaN

# %%
# Build a dataset with every possible (UserID, ProductID) pair (cross join)
session_user_cross = df3.merge(df1,how='cross')
session_user_cross.head()
# Out:
#    SessionID SessionDate  UserID_x  UserID_y      User  Gender Registered  \
# 0          1  2010-01-05         2         1   Charles    male 2012-12-21
# 1          1  2010-01-05         2         2     Pedro    male 2010-08-01
# 2          1  2010-01-05         2         3  Caroline  female 2012-10-23
# 3          1  2010-01-05         2         4   Brielle  female 2013-07-17
# 4          1  2010-01-05         2         5  Benjamin    male 2010-11-25
#
#     Cancelled
# 0         NaN
# 1  2010-08-08
# 2  2016-06-07
# 3         NaN
# 4         NaN

# %%
transaction_user_cross = df4.merge(df1,how='cross')
transaction_user_cross.head
# Out:
#    TransactionID TransactionDate  UserID_x  ProductID  Quantity  UserID_y  \
# 0              1      2010-08-21       7.0          2         1         1
# 1              1      2010-08-21       7.0          2         1         2
# 2              1      2010-08-21       7.0          2         1         3
# 3              1      2010-08-21       7.0          2         1         4
# 4              1      2010-08-21       7.0          2         1         5
#
#        User  Gender Registered   Cancelled
# 0   Charles    male 2012-12-21         NaN
# 1     Pedro    male 2010-08-01  2010-08-08
# 2  Caroline  female 2012-10-23  2016-06-07
# 3   Brielle  female 2013-07-17         NaN
# 4  Benjamin    male 2010-11-25         NaN

# %%
transaction_product_cross = df4.merge(df2,how='cross')
transaction_product_cross.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID_x  Quantity  ProductID_y  \
# 0              1      2010-08-21     7.0            2         1            1
# 1              1      2010-08-21     7.0            2         1            2
# 2              1      2010-08-21     7.0            2         1            3
# 3              1      2010-08-21     7.0            2         1            4
# 4              1      2010-08-21     7.0            2         1            5
#
#   Product  Price
# 0       A  14.16
# 1       B  33.04
# 2       C  10.65
# 3       D  10.02
# 4       E  29.66

# %%
# Determine how much quantity of each product was purchased by each user
df=df2.merge(df4.merge(df1,how='outer',on='UserID'),how='outer',on='ProductID')
df.groupby(['User','Product'])['Quantity'].sum()
# Out:
# User      Product
# Caroline  C          1.0
#           D          6.0
# Charles   B          3.0
# Pedro     D          1.0
#           E          6.0
# Name: Quantity, dtype: float64

# %%
# For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
# Join each user to his/her first occuring transaction in the transactions table
transaction_User = df4.merge(df1,how='left',on='UserID')
df = transaction_User.sort_values(by=['UserID', 'TransactionDate'])
df = df.groupby('UserID').first().reset_index()
first_transaction = transaction_User.merge(df,how='left',on='UserID')
first_transaction
# Out:
#    TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                1        2010-08-21     7.0            2           1
# 1                2        2011-05-26     3.0            4           1
# 2                3        2011-06-16     3.0            3           1
# 3                4        2012-08-26     1.0            2           3
# 4                5        2013-06-06     2.0            4           1
# 5                6        2013-12-23     2.0            5           6
# 6                7        2013-12-30     3.0            4           1
# 7                8        2014-04-24     NaN            2           3
# 8                9        2015-04-24     7.0            4           3
# 9               10        2016-05-08     3.0            4           4
#
#      User_x Gender_x Registered_x Cancelled_x  TransactionID_y  \
# 0       NaN      NaN          NaT         NaN              1.0
# 1  Caroline   female   2012-10-23  2016-06-07              2.0
# ...

# %%
# Test to see if we can drop columns
